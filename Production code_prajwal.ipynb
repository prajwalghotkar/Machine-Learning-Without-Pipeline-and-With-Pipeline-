# %%
import pickle
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pmgho'

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.condarc', '.continuum', '.cufflinks', '.gitconfig', '.gradio', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.vscode', '1NPDPRO5.DOC', '2Data Preprocessing.ipynb', 'AppData', 'Application Data', 'Column Transformer.ipynb', 'Conditional Statement prajwal.ipynb', 'Contacts', 'Cookies', 'Data Preprocessing.ipynb', 'demo.ipynb', 'Desktop', 'Documents', 'Downloads', 'Drug Prediction prajwal.ipynb', 'EDA.ipynb', 'Favorites', 'Feature Scaling - Standardization.ipynb', 'Flight Price Prediction Heroku.ipynb', 'For Loop.ipynb', 'House_Price_Processing(By Prajwal).ipynb', 'java_error_in_pycharm.hprof', 'Links', 'Local Settings', 'Machine Learning Piplines.ipynb', 'main.ipynb', 'Microsoft', 'Music', 'My Documents', 'myenv', 'NetHood', 'Normalization.ipynb', 'NPProt.bkp', 'NPProt.exe', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{e109ab0e-e3bd-11ef-9675-bdee83d50eaa}.TxR.0.regtrans-ms', 'NTUSER.DAT{e109ab0e-e3bd-11ef-9675-bdee83d50eaa}.
# ...

# %%
import os
print(os.listdir('C:\\Users\\pmgho\\Downloads\\Prajwal Machine Learning Data Set\\'))
# Out:
# ['.idea', '.ipynb_checkpoints', 'cars.csv', 'covid_toy.csv', 'Customer Purchase.csv', 'Data Preprocessing Data File.xlsx', 'Data Preprocessing Example.xlsx', 'House_Price_Preprocessing.csv', 'prajwalmodels_clf.pkl', 'prajwalmodels_ohe_embarked.pkl', 'prajwalmodels_ohe_sex.pkl', 'Prajwal_pipe.pkl', 'project.ipynb', 'python', 'Social_Network_Ads.csv', 'titanic.csv', 'train.csv', 'wine.data.csv', 'wine2data.csv']

# %%
import pickle


pipe = pickle.load(open('C:\\Users\\pmgho\\Downloads\\Prajwal Machine Learning Data Set\\Prajwal_pipe.pkl', 'rb'))

# %%
pickle.dump(pipe, open('Prajwal_pipe.pkl', 'wb'))

# %%
pipe = pickle.load(open('Prajwal_pipe.pkl','rb'))

# %%
pipe
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_age', SimpleImputer(),
#                                                   [2]),
#                                                  ('impute_embarked',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6])])),
#                 ('trf2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one_hot_encoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [1, 6])])),
#                 ('trf3',
#                  ColumnTransformer(transformers=[('scale', MinMaxScaler(),
# ...

# %%
# Assume user input

test_input = np.array([2, 'male', 31.0,0,0,10.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
##### Prajwal
